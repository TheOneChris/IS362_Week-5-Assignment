# %%
import pandas as pd

airports = pd.read_csv('airports.csv')
weathers = pd.read_csv('weather.csv')
airlines = pd.read_csv('airlines.csv')
planes = pd.read_csv('planes.csv')

# %%
# This sorts the airports by the lat colume which tells us the most north airport
airports.sort_values(by=["lat"], ascending=False)
# Out:
#       faa                                        name        lat         lon  \
# 417   EEN                     Dillant Hopkins Airport  72.270833   42.898333
# 230   BRW                  Wiley Post Will Rogers Mem  71.285446 -156.766003
# 110   AIN                          Wainwright Airport  70.638056 -159.994722
# 708   K03                               Wainwright As  70.613378 -159.860350
# 152   ATK  Atqasuk Edward Burnell Sr Memorial Airport  70.467300 -157.436000
# ...   ...                                         ...        ...         ...
# 930   MUE                               Waimea Kohala  20.001328 -155.668108
# 1403  WKL                           Waikoloa Heliport  19.913600 -155.864000
# 231   BSF                                Bradshaw Aaf  19.760056 -155.553717
# 734   KOA                        Kona Intl At Keahole  19.738767 -156.045631
# 679   ITO                                   Hilo Intl  19.721375 -155.048469
#
#        alt  tz dst              tzone
# ...

# %%
airports.sort_values(by=["lon"], ascending=False)
# Out:
#       faa                           name        lat         lon   alt  tz dst  \
# 1290  SYA                   Eareckson As  52.712275  174.113620    98  -9   A
# 942   MYF               Montgomery Field  32.475900  117.759000    17   8   A
# 396   DVT  Deer Valley Municipal Airport  33.411700  112.457000  1478   8   A
# 417   EEN        Dillant Hopkins Airport  72.270833   42.898333   149  -5   A
# 444   EPM     Eastport Municipal Airport  44.910111  -67.012694    45  -5   A
# ...   ...                            ...        ...         ...   ...  ..  ..
# 1251  SNP                 St Paul Island  57.167333 -170.220444    63  -9   A
# 1281  SVA               Savoonga Airport  63.686400 -170.493000    53  -9   A
# 522   GAM                Gambell Airport  63.766800 -171.733000    27  -9   A
# 112   AKB                   Atka Airport  52.220278 -174.206389    56  -9   A
# 95    ADK                   Adak Airport  51.878000 -176.646000    18  -9   A
#
#                   tzone
# ...

# %%
weathers[(weathers["month"]==2) & (weathers["day"]==12) & (weathers["year"]==2013)].sort_values(by=["wind_gust"], ascending=False)
# Out:
#       origin  year  month  day  hour   temp   dewp  humid  wind_dir  \
# 1018     EWR  2013      2   12    12  44.06  26.06  48.87     270.0
# 1019     EWR  2013      2   12    13  46.04  26.06  45.33     280.0
# 18417    LGA  2013      2   12     2  42.98  26.06  50.94     290.0
# 18421    LGA  2013      2   12     6  42.08  24.08  48.56     270.0
# 18418    LGA  2013      2   12     3  42.08  26.06  52.73     290.0
# ...      ...   ...    ...  ...   ...    ...    ...    ...       ...
# 18431    LGA  2013      2   12    16  42.98  24.08  46.91     300.0
# 18435    LGA  2013      2   12    20  39.92  23.00  50.46     290.0
# 18436    LGA  2013      2   12    21  39.02  21.92  49.93     310.0
# 18437    LGA  2013      2   12    22  39.02  23.00  52.26     310.0
# 18438    LGA  2013      2   12    23  37.94  23.00  54.51     300.0
#
#        wind_speed  wind_gust  precip  pressure  visib             time_hour
# ...

# %%
#RESULTS AND ANSWERS TO QUESTIONS

#Question 1: What is the northernmost airport in the United States?

#Answer: According to the datasets in the northern most airport is Dillant Hopkins Airport with a latitude of 72.27 while the northern most United States Airport is Wiley Post Will Rogers Memorial Airport with a latitude of 71.28

#Justification: Latitude is a measure of how close someone or something is to the north or south poles from the Equator which is the half waypoint between the 2 poles. The higher the number the further you are north or south, considering that the United States is above the Equator and occupies between 18.55 and 71.30 latitude, Wiley Post Will Rogers Memorial Airport is the northern most airport.


#Question 2: What is the easternmost airport in the United States?

#Answer: According to the datasets the eastern most airport is Eareckson As Airport with a Longitude of 174.11.

#Justification: Longitude is a measure of angular distance someone or something  is east or west  of the Prime Meridian. Which is  0 and 180 on a latitude and longitude map. When measuring how far east or west a place is you either move to the left or right of the prime meridian, for east to move to the right and for west to move to the left, starting at 0 and moving up until you reach the point and measure it. With that said the eastern most airport is Eareckson As Airport being 174.11 east of the prime meridian.


#Question 3: On February 12th, 2013, which New York area airport had the windiest weather?

#Answer: According to the datasets the windiest airport in NY on 2/12/2013 was LGA or LaGuardia Airport

#Justification: EWR is located in Newark, New Jersey (NJ) not New York (NY). Therefore while it had high wind gust at the same level of LGA, the location disqualifies it.
